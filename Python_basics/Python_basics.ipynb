# %% [markdown]
# # Python basics
#
# ## Topics covered:
#
# - Comments
# - Data Types
# - Mathematical Ops
# - Inbuilt functions(len, type)
# - Strings(basics)
# - Variable Assignment
# - Various ways of printing

# %%
#This is a comment

# %%
10 * 'aryan'
# Out:
# 'aryanaryanaryanaryanaryanaryanaryanaryanaryanaryan'

# %%
10 ** 2
# Out:
# 100

# %%
type(True)
# Out:
# bool

# %%
type(2 + 6j) #use j for i in python... 2+6i gives an error
# Out:
# complex

# %%
len("aryan")
# Out:
# 5

# %%
#While applying Mathematical ops, Bodmas will be followed.

# %%
#Various ways of printing

first_name = "aryan"
last_name = "goyal"

print(first_name , last_name) #first_name + last_name is string concatenation and space isnt there
print("My first name is {} and last name is {}" .format(first_name, last_name)) #here order is important inside format fn
print("My first name is {first} and last name is {last}" .format(last = last_name, first = first_name)) #Here the
# Out:
# aryan goyal
# My first name is aryan and last name is goyal
# My first name is aryan and last name is goyal

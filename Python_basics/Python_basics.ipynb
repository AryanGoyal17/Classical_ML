# %% [markdown]
# # Python basics
#
# ## 1_Topics covered:
#
# - Comments
# - Data Types
# - Mathematical Ops
# - Inbuilt functions(len, type)
# - Strings(basics)
# - Variable Assignment
# - Various ways of printing
# - Boolean variables
# - String Methods(isalnum, isalpha, isdigit, istitle, isspace, isupper, islower, endswith, startswith)
# - Boolean Logical Operations
#
# ## 2_Python Data Structures:
#
# - Lists
# - Sets
# - Dictionaries
# - Tuples

# %%
#This is a comment

# %%
10 * 'aryan'
# Out:
# 'aryanaryanaryanaryanaryanaryanaryanaryanaryanaryan'

# %%
10 ** 2
# Out:
# 100

# %%
type(True)
# Out:
# bool

# %%
type(2 + 6j) #use j for i in python... 2+6i gives an error
# Out:
# complex

# %%
len("aryan")
# Out:
# 5

# %%
#While applying Mathematical ops, Bodmas will be followed.

# %%
#Various ways of printing

first_name = "aryan"
last_name = "goyal"

print(first_name , last_name) #first_name + last_name is string concatenation and space isnt there
print("My first name is {} and last name is {}" .format(first_name, last_name)) #here order is important inside format fn
print("My first name is {first} and last name is {last}" .format(last = last_name, first = first_name)) #Here the
# Out:
# aryan goyal
# My first name is aryan and last name is goyal
# My first name is aryan and last name is goyal

# %%
#Revise string methods from Learning_Python repo

# %%
#Boolean Logical Ops

# %%
True or False
# Out:
# True

# %%
str1 = "Hello"
str2 = "abc123"

print(str1.isalpha() or str2.isnum())
# print(str1.isalpha() and str2.isnum())

#isnum doesnt exist in python... if you uncomment above line.. it shows error
#First line returned true because for or if the first part is true the kernel(interpretor) of python stops reading

print(str1.isalpha() or str2.isdigit())
print(str1.isalpha() and str2.isdigit())
# Out:
# True
# True
# False

# %%
##

# %%
##Python Data Structures

#1-- Lists
